# %%
from IPython.display import Image
Image(filename='Number Card.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Text Card.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Date Card.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Multi Row Card.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Filter on visual.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Filter on page.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Drillthrough.png',width=800,height=800)
