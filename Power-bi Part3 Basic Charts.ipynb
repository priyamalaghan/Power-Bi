# %%
from IPython.display import Image
Image(filename='simple column chart.png',width=600,height=600)

# %%
from IPython.display import Image
Image(filename='Stacked.png',width=600,height=600)

# %%
from IPython.display import Image
Image(filename='include.png',width=600,height=600)

# %%
from IPython.display import Image
Image(filename='exclude.png',width=600,height=600)

# %%
from IPython.display import Image
Image(filename='pie.png',width=600,height=600)

# %%
from IPython.display import Image
Image(filename='Donut.png',width=600,height=600)

# %%
from IPython.display import Image
Image(filename='Funnel.png',width=600,height=600)

# %%
from IPython.display import Image
Image(filename='ribbon.png',width=600,height=600)

# %%
from IPython.display import Image
Image(filename='View Data and Export.png',width=600,height=600)
