# %% [markdown]
# # Actions

# %%
from IPython.display import Image
Image(filename='Insert Objects.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Action Page.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Bookmark Action.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Drill through action.png',width=800,height=800)
