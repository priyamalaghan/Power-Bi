# %%
from IPython.display import Image
Image(filename='Area Chart.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Line Chart.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Drill down line chart.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Line Vs Column Chart.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Scatter Plot.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Waterfall Chart.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='TreeMap.png',width=800,height=800)

# %%
from IPython.display import Image
Image(filename='Guage Chart.png',width=800,height=800)
